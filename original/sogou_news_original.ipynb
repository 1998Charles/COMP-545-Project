# %%
import time
import fasttext
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import accuracy_score

# %%
sogou_news = load_dataset("sogou_news")
print(sogou_news)
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['title', 'content', 'label'],
#         num_rows: 60000
#     })
#     train: Dataset({
#         features: ['title', 'content', 'label'],
#         num_rows: 450000
#     })
# })

# %%
print(type(sogou_news['train']['title']))
print(type(sogou_news['train']['title'][0]))
print(sogou_news['train']['title'][0])
print(type(sogou_news['train']['content']))
print(type(sogou_news['train']['content'][0]))
print(sogou_news['train']['content'][0])
print(type(sogou_news['train']['label']))
print(type(sogou_news['train']['label'][0]))
print(sogou_news['train']['label'][0])
# Out:
# <class 'list'>
# <class 'str'>
# 2008 di4 qi1 jie4 qi1ng da3o guo2 ji4 che1 zha3n me3i nv3 mo2 te4
# <class 'list'>
# <class 'str'>
# 2008di4 qi1 jie4 qi1ng da3o guo2 ji4 che1 zha3n yu2 15 ri4 za4i qi1ng da3o guo2 ji4 hui4 zha3n zho1ng xi1n she4ng da4 ka1i mu4 . be3n ci4 che1 zha3n jia1ng chi2 xu4 da4o be3n yue4 19 ri4 . ji1n nia2n qi1ng da3o guo2 ji4 che1 zha3n shi4 li4 nia2n da3o che2ng che1 zha3n gui1 mo2 zui4 da4 di2 yi1 ci4 , shi3 yo4ng lia3o qi1ng da3o guo2 ji4 hui4 zha3n zho1ng xi1n di2 qua2n bu4 shi4 ne4i wa4i zha3n gua3n . yi3 xia4 we2i xia4n cha3ng mo2 te4 tu2 pia4n .
# <class 'list'>
# <class 'int'>
# 3

# %%
print(type(sogou_news['test']['title']))
print(type(sogou_news['test']['title'][0]))
print(sogou_news['test']['title'][0])
print(type(sogou_news['test']['content']))
print(type(sogou_news['test']['content'][0]))
print(sogou_news['test']['content'][0])
print(type(sogou_news['test']['label']))
print(type(sogou_news['test']['label'][0]))
print(sogou_news['test']['label'][0])
# Out:
# <class 'list'>
# <class 'str'>
#  ti3 ca1o shi4 jie4 be1i : che2ng fe1i na2 pi2ng he2ng mu4 zi4 yo2u ca1o ji1n pa2i
# <class 'list'>
# <class 'str'>
# su4 du4 : ( shuo1 mi2ng : dia3n ji1 zi4 do4ng bo1 fa4ng )\n  shuo1 mi2ng : dia3n ji1 ga1i a4n niu3 , xua3n ze2 yi1 lu4n ta2n ji2 ke3
# <class 'list'>
# <class 'int'>
# 0

# %%
def print_results(N, p, r):
    print("N\t" + str(N))
    print("P@{}\t{:.3f}".format(1, p))
    print("R@{}\t{:.3f}".format(1, r))

# %%
dataset = sogou_news

# %%
titles = dataset['train']['title']
contents = dataset['train']['content']
train_texts = [str(x) + str(y) for x, y in zip(titles, contents)]
train_labels = dataset['train']['label']

with open("train.txt", "w") as f:
    for text, label in zip(train_texts, train_labels):
        f.write(f"__label__{label} {text}\n")

# %%
titles = dataset['test']['title']
contents = dataset['test']['content']
test_texts = [str(x) + str(y) for x, y in zip(titles, contents)]
test_labels = dataset['test']['label']

with open("test.txt", "w") as f:
    for text, label in zip(test_texts, test_labels):
        f.write(f"__label__{label} {text}\n")

# %%
lr_list = [0.05, 0.1, 0.25, 0.5]
dim_list = [10] # hidden units
ngrams_list = [1]
epoch_list = [5]

best_p, best_r = 0, 0
best_l, best_d, best_n, best_e = 0, 0, 0, 0

for l in lr_list:
    for d in dim_list:
        for n in ngrams_list:
            for e in epoch_list:
                print(f"Training model with lr={l}, dim={d}, epoch={e}, and wordNgrams={n}")
                model = fasttext.train_supervised(input='train.txt', lr=l, dim=d, epoch=e, wordNgrams=n)
                N, p, r = model.test('test.txt')
                print_results(N, p, r)
                if p > best_p and r > best_r:
                    best_p, best_r = p, r
                    best_l, best_d, best_n, best_e = l, d, n, e
                print()
# Out:
# Training model with lr=0.05, dim=10, epoch=5, and wordNgrams=1
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 13790429 lr:  0.000000 avg.loss:  0.280437 ETA:   0h 0m 0s 0s
# Read 6M words
# N	60000
# P@1	0.929
# R@1	0.929
#
# Training model with lr=0.1, dim=10, epoch=5, and wordNgrams=1
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 13691217 lr:  0.000000 avg.loss:  0.270712 ETA:   0h 0m 0s
# N	60000
# P@1	0.926
# R@1	0.926
#
# Training model with lr=0.25, dim=10, epoch=5, and wordNgrams=1
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 13199295 lr:  0.000000 avg.loss:  0.267300 ETA:   0h 0m 0s
# N	60000
# P@1	0.929
# R@1	0.929
#
# Training model with lr=0.5, dim=10, epoch=5, and wordNgrams=1
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 13357859 lr:  0.000000 avg.loss:  0.268688 ETA:   0h 0m 0s
# N	60000
# P@1	0.929
# R@1	0.929

# %%
print(f"Training the best model with lr={best_l}, dim={best_d}, epoch={best_e}, and wordNgrams={best_n}")

start_time = time.time()
model = fasttext.train_supervised(input='train.txt', lr=best_l, dim=best_d, epoch=best_e, wordNgrams=best_n, verbose=2)
# Out:
# Training the best model with lr=0.25, dim=10, epoch=5, and wordNgrams=1
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 12543069 lr:  0.000000 avg.loss:  0.266953 ETA:   0h 0m 0s

# %%
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")

predictions = []
for text in test_texts:
    prediction = model.predict(text)
    predictions.append(int(prediction[0][0].split('__label__')[1]))
accuracy = accuracy_score(test_labels, predictions)
print("Accuracy:", accuracy)
# Out:
# Elapsed time: 21.671905994415283 seconds
# Accuracy: 0.9331666666666667

# %%
lr_list = [0.05, 0.1, 0.25, 0.5]
dim_list = [10] # hidden units
ngrams_list = [2]
epoch_list = [5]

best_p, best_r = 0, 0
best_l, best_d, best_n, best_e = 0, 0, 0, 0

for l in lr_list:
    for d in dim_list:
        for n in ngrams_list:
            for e in epoch_list:
                print(f"Training model with lr={l}, dim={d}, epoch={e}, and wordNgrams={n}")
                model = fasttext.train_supervised(input='train.txt', lr=l, dim=d, epoch=e, wordNgrams=n)
                N, p, r = model.test('test.txt')
                print_results(N, p, r)
                if p > best_p and r > best_r:
                    best_p, best_r = p, r
                    best_l, best_d, best_n, best_e = l, d, n, e
                print()
# Out:
# Training model with lr=0.05, dim=10, epoch=5, and wordNgrams=2
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 8827926 lr:  0.000000 avg.loss:  0.227526 ETA:   0h 0m 0s
# N	60000
# P@1	0.955
# R@1	0.955
#
# Training model with lr=0.1, dim=10, epoch=5, and wordNgrams=2
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress:  99.7% words/sec/thread: 7941214 lr:  0.000266 avg.loss:  0.184419 ETA:   0h 0m 0s
# N	60000
# P@1	0.960
# R@1	0.960
#
# Training model with lr=0.25, dim=10, epoch=5, and wordNgrams=2
# Progress: 100.0% words/sec/thread: 7927713 lr:  0.000000 avg.loss:  0.184348 ETA:   0h 0m 0s
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 8794321 lr:  0.000000 avg.loss:  0.149481 ETA:   0h 0m 0s
# N	60000
# P@1	0.962
# R@1	0.962
#
# Training model with lr=0.5, dim=10, epoch=5, and wordNgrams=2
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 8676917 lr:  0.000000 avg.loss:  0.139206 ETA:   0h 0m 0s
# N	60000
# P@1	0.963
# R@1	0.963

# %%
print(f"Training the best model with lr={best_l}, dim={best_d}, epoch={best_e}, and wordNgrams={best_n}")

start_time = time.time()
model = fasttext.train_supervised(input='train.txt', lr=best_l, dim=best_d, epoch=best_e, wordNgrams=best_n, verbose=2)
# Out:
# Training the best model with lr=0.5, dim=10, epoch=5, and wordNgrams=2
# Read 255M words
# Number of words:  819445
# Number of labels: 5
# Progress: 100.0% words/sec/thread: 8601081 lr:  0.000000 avg.loss:  0.139926 ETA:   0h 0m 0s

# %%
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")

predictions = []
for text in test_texts:
    prediction = model.predict(text)
    predictions.append(int(prediction[0][0].split('__label__')[1]))
accuracy = accuracy_score(test_labels, predictions)
print("Accuracy:", accuracy)
# Out:
# Elapsed time: 28.326147079467773 seconds
# Accuracy: 0.9641166666666666
